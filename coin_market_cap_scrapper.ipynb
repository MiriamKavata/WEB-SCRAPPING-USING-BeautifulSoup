# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://coinmarketcap.com/ico-calendar/ended/'
page = requests.get(url)
soup = BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><meta charset="utf-8"/><meta content="ie=edge" http-equiv="x-ua-compatible"/><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, shrink-to-fit=no" name="viewport"/><script>(function() {var isInApp = navigator.userAgent.match(/CMCApp/i);if (!isInApp && !window.oneTrustScriptLoad) {window.oneTrustScriptLoad = true;document.write('<scr'+'ipt src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8" data-domain-script="13729615-a271-4a5f-8eae-0c058b458464"></sc'+'ript><scr'+'ipt type="text/javascript"> function OptanonWrapper() {} </sc'+'ript>');}
# ...

# %%
soup.find('table')
# Out:
# <table class="sc-b28ea1c6-3 lbgWUb cmc-table"><colgroup><col style="width:220px;min-width:auto;max-width:auto"/><col style="width:220px;min-width:auto;max-width:auto"/><col style="width:220px;min-width:auto;max-width:auto"/><col style="width:220px;min-width:auto;max-width:auto"/><col style="width:220px;min-width:auto;max-width:auto"/><col style="width:120px;min-width:auto;max-width:auto"/><col style="width:220px;min-width:auto;max-width:auto"/></colgroup><thead><tr><th class="stickyTop" style="text-align:left"><div class="sc-e2bf8e45-0 hIxkXT"><div class="sc-e2bf8e45-1 jWa-dwd"><p class="sc-4984dd93-0 fiHcNM" color="text" data-sensors-click="true" font-size="0">Project</p><span class="sc-e2bf8e45-2 eWItEG"></span></div></div></th><th class="stickyTop" style="text-align:right"><div class="sc-e2bf8e45-0 soeuE"><div class="sc-e2bf8e45-1 jWa-dwd"><span class="sc-e2bf8e45-2 eWItEG"></span><p class="sc-4984dd93-0 fiHcNM" color="text" data-sensors-click="true" font-size="0">ICO Price</p></d
# ...

# %%
#Initialize empty lists to store data
project =[]
stage = []
start_date = []
end_date = []
goal = []

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# Initialize lists to store data
project = []
ico_price = []
stage = []
start_date = []
end_date = []
goal = []

# Loop through multiple pages (adjust the range as needed)
for page_number in range(1, 14):  # Example: Loop through pages 1 to 13
    url = f'https://coinmarketcap.com/ico-calendar/ended/?page={page_number}'
    page = requests.get(url).text
    soup = BeautifulSoup(page, 'html.parser')
    table = soup.find('table', {'class': 'cmc-table'})

    for row in table.find_all('tr')[1:]:
        columns = row.find_all('td')

        if len(columns) >= 6:
            project.append(columns[0].text.strip())
            ico_price.append(columns[1].text.strip())
            stage.append(columns[2].text.strip())
            start_date.append(columns[3].text.strip())
            end_date.append(columns[4].text.strip())
            goal.append(columns[5].text.strip())

# Create a DataFrame from the collected data
data = {
    "Project": project,
    "Ico Price": ico_price,
    "Stage": stage,
    "Start date": start_date,
    "End date": end_date,
    "Goal": goal
}

df = pd.DataFrame(data)
print(df)
# Out:
#                                          Project  Ico Price  \
# 0     Polygonum OnlinePOGBNB Smart Chain (BEP20)  $0.080000
# 1                              SOLA-XSAXEthereum  $0.030000
# 2                                   AltitudeALTD  $0.600000
# 3                             Virtual VersionsVV         --
# 4                             PatexPATEXEthereum  $0.950000
# ...                                          ...        ...
# 1215                         HarmonyONEbnb-chain  $0.006500
# 1216         PolygonMATICBNB Smart Chain (BEP20)  $0.002630
# 1217    Celer NetworkCELRBNB Smart Chain (BEP20)         --
# 1218          Fetch.aiFETBNB Smart Chain (BEP20)         --
# 1219     BitTorrentBTTOLDBNB Smart Chain (BEP20)         --
#
#                      Stage    Start date      End date        Goal
# 0     IDOended 2 years ago            --  Nov 24, 2021     $98,000
# 1      IDOended 6 days ago  Aug 24, 2023  Aug 31, 2023     $80,000
# ...

# %%
df.to_csv(r'C:\Users\Kavata Muia\Desktop\CO-OP\ENDED PROJECTS.csv')
